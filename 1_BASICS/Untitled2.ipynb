# %%
import random

salary_list = [random.randint(1,10) for i in range(10_000_000)]
#print(salary_list)

# %%
import statistics

# %%
# %%timeit

#add all values and divide by number of occuring

statistics.mean(salary_list)
# Out:
# 2.79 s ± 416 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
import numpy as np

# %%
# %%timeit
np.mean(salary_list)
# Out:
# 621 ms ± 37.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
my_array = np.array([1,2,3,4,5])
print(my_array.mean())
# Out:
# 3.0

# %%
import pandas as pd

file = pd.read_csv('/content/sample_data/california_housing_test.csv')

# %%
print(file.total_bedrooms[1])
# Out:
# 310.0

# %%
file = pd.read_csv('/content/sample_data/data_jobs.csv')
# Out:
# <ipython-input-5-5a191915d7da>:1: DtypeWarning: Columns (5,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   file = pd.read_csv('/content/sample_data/data_jobs.csv')

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242776 entries, 0 to 242775
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        242776 non-null  object
#  1   job_title              242776 non-null  object
#  2   job_location           242514 non-null  object
#  3   job_via                242773 non-null  object
#  4   job_schedule_type      238946 non-null  object
#  5   job_work_from_home     242776 non-null  bool
#  6   search_location        242776 non-null  object
#  7   job_posted_date        242776 non-null  object
#  8   job_no_degree_mention  242775 non-null  object
#  9   job_health_insurance   242775 non-null  object
#  10  job_country            242760 non-null  object
#  11  salary_rate            9861 non-null    object
#  12  salary_year_avg        6481 non-null    float64
#  13  salary_hour_avg        3267 non-null    float64
# ...

# %%
file[['job_title', 'job_location']].head(11)
# Out:
#                                             job_title  \
# 0   Senior Clinical Data Engineer / Principal Clin...
# 1                                        Data Analyst
# 2   Data Engineer/Scientist/Analyst, Mid or Senior...
# 3   LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                              Data Engineer- Sr Jobs
# 5                                   GCP Data Engineer
# 6                   Senior Data Engineer  - GCP Cloud
# 7                                       Data Engineer
# 8            Technology & Operations Business Analyst
# 9                                   Data Scientist II
# 10               Erfahrene*r Data Engineer*in (m/w/d)
#
#                     job_location
# 0                  Watertown, CT
# 1   Guadalajara, Jalisco, Mexico
# 2                Berlin, Germany
# 3                San Antonio, TX
# 4                 Washington, DC
# 5                       Anywhere
# 6                   Dearborn, MI
# 7                       Anywhere
# ...

# %%
file.iloc[10:15]
# Out:
#          job_title_short                                    job_title  \
# 10         Data Engineer         Erfahrene*r Data Engineer*in (m/w/d)
# 11         Data Engineer                                Data Engineer
# 12          Data Analyst  Stagiaire Data Analyst (H/F) - Lyon (69006)
# 13  Senior Data Engineer                         Senior Data Engineer
# 14         Data Engineer                                Data Engineer
#
#                                        job_location       job_via  \
# 10                               Basel, Switzerland  via LinkedIn
# 11               Colorado Springs, CO   (+3 others)  via The Muse
# 12                                     Lyon, France  via Jobijoba
# 13                                     New York, NY  via LinkedIn
# 14  Rio de Janeiro, State of Rio de Janeiro, Brazil     via BeBee
#
#            job_schedule_type  job_work_from_home       search_location  \
# 10                 Full-time               False           Switzerland
# ...

# %%
file.loc[5:10,['job_title', 'job_location']]
# Out:
#                                    job_title         job_location
# 5                          GCP Data Engineer             Anywhere
# 6          Senior Data Engineer  - GCP Cloud         Dearborn, MI
# 7                              Data Engineer             Anywhere
# 8   Technology & Operations Business Analyst  Copenhagen, Denmark
# 9                          Data Scientist II             Anywhere
# 10      Erfahrene*r Data Engineer*in (m/w/d)   Basel, Switzerland

# %%
file[['job_title', 'job_location']].iloc[5:10]
# Out:
#                                   job_title         job_location
# 5                         GCP Data Engineer             Anywhere
# 6         Senior Data Engineer  - GCP Cloud         Dearborn, MI
# 7                             Data Engineer             Anywhere
# 8  Technology & Operations Business Analyst  Copenhagen, Denmark
# 9                         Data Scientist II             Anywhere

# %%
file['job_title_short'].unique()
# Out:
# array(['Senior Data Engineer', 'Data Analyst', 'Data Engineer',
#        'Business Analyst', 'Data Scientist', 'Machine Learning Engineer',
#        'Senior Data Analyst', 'Cloud Engineer', 'Senior Data Scientist',
#        'Software Engineer'], dtype=object)

# %%
file[file.job_title_short == 'Data Analyst']
# Out:
#        job_title_short                                          job_title  \
# 1         Data Analyst                                       Data Analyst
# 12        Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18        Data Analyst                                       Data Analyst
# 31        Data Analyst                           Stage - Data Analyst F/H
# 34        Data Analyst  Data Analyst als Marketing Manager Automation ...
# ...                ...                                                ...
# 242758    Data Analyst                          Data Privacy Analyst (FE)
# 242759    Data Analyst                     Data Analyst- Trainee Freshers
# 242761    Data Analyst                                  CP Analyst – Data
# 242765    Data Analyst                               Senior, Data Analyst
# 242766    Data Analyst                            Data Management Analyst
#
#                                       job_location  \
# ...

# %%
file[(file.job_title_short == 'Data Analyst') & (file.salary_year_avg > 100000)]
# Out:
#        job_title_short                                          job_title  \
# 410       Data Analyst        IT Business Lead Data Analyst - VP - Hybrid
# 1555      Data Analyst                      Data Analyst/Engineer (M/F/D)
# 1681      Data Analyst                                       Data Analyst
# 1684      Data Analyst                           Data Analyst - Data17829
# 1867      Data Analyst      Data Integration Analyst (West Coast/Chicago)
# ...                ...                                                ...
# 239735    Data Analyst  Supervisory Operations Research Analyst (Data ...
# 240910    Data Analyst                    Senior specialist, Data Analyst
# 240949    Data Analyst  Research Scientist / Research Engineer (Greate...
# 241725    Data Analyst               Security Vuln Metrics & Data Analyst
# 242081    Data Analyst                      Real Estate Data Analyst 1LOD
#
#                                  job_location               job_via  \
# ...

# %%
file.job_posted_date[0]
# Out:
# '2023-06-16 13:44:15'

# %%
pd.to_datetime(file.job_posted_date)
# Out:
# 0        2023-06-16 13:44:15
# 1        2023-01-14 13:18:07
# 2        2023-10-10 13:14:55
# 3        2023-07-04 13:01:41
# 4        2023-08-07 14:29:36
#                  ...
# 430220   2023-11-08 16:23:47
# 430221   2023-03-02 16:41:58
# 430222   2023-03-29 16:00:50
# 430223   2023-11-15 16:16:12
# 430224                   NaT
# Name: job_posted_date, Length: 430225, dtype: datetime64[ns]

# %%
file['job_posted_date'] = pd.to_datetime(file.job_posted_date)
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 430225 entries, 0 to 430224
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        430225 non-null  object
#  1   job_title              430224 non-null  object
#  2   job_location           429701 non-null  object
#  3   job_via                430221 non-null  object
#  4   job_schedule_type      423565 non-null  object
#  5   job_work_from_home     430224 non-null  object
#  6   search_location        430224 non-null  object
#  7   job_posted_date        430224 non-null  datetime64[ns]
#  8   job_no_degree_mention  430224 non-null  object
#  9   job_health_insurance   430224 non-null  object
#  10  job_country            430200 non-null  object
#  11  salary_rate            17690 non-null   object
#  12  salary_year_avg        11250 non-null   float64
#  13  salary_hour_avg        6216 non-null    float64
# ...

# %%
file['job_posted_month'] = file.job_posted_date.dt.month.

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11250 entries, 108883 to 327439
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        11250 non-null  object
#  1   job_title              11250 non-null  object
#  2   job_location           11107 non-null  object
#  3   job_via                11250 non-null  object
#  4   job_schedule_type      11240 non-null  object
#  5   job_work_from_home     11250 non-null  object
#  6   search_location        11250 non-null  object
#  7   job_posted_date        11250 non-null  datetime64[ns]
#  8   job_no_degree_mention  11250 non-null  object
#  9   job_health_insurance   11250 non-null  object
#  10  job_country            11250 non-null  object
#  11  salary_rate            11250 non-null  object
#  12  salary_year_avg        11250 non-null  float64
#  13  company_name           11250 non-null  object
# ...

# %%
file.drop('salary_hour_avg', axis=1, inplace = True)

# %%
file.dropna(subset='salary_year_avg', inplace = True)
