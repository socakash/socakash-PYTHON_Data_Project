# %% [markdown]
# # What are the most demanded skills for the top-3 most popular job roles
#
# 1- clean skills column

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import ast
import seaborn as sns

df = pd.read_csv("C:/Users/akash/Downloads/PYTHON/data_jobs.csv")

# %% [markdown]
# # Clean Job_posted_date to date time frame
# # clean job skills str to list

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

df.dropna(subset= ['job_skills'], inplace= True)

df['job_skills'] = df['job_skills'].apply(lambda skills : ast.literal_eval(skills) )

# %%
df_new = df.copy()
df_new
# Out:
#           job_title_short                                          job_title  \
# 1            Data Analyst                                       Data Analyst
# 2           Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3           Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4           Data Engineer                             Data Engineer- Sr Jobs
# 5           Data Engineer                                  GCP Data Engineer
# ...                   ...                                                ...
# 785736  Software Engineer                                    DevOps Engineer
# 785737       Data Analyst                                   CRM Data Analyst
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst
#
# ...

# %% [markdown]
# # filter large dataset for Country = USA and Role Data Analyst

# %%
df_da_us = df_new[(df_new.job_country =='United States') & (df_new.job_title_short == 'Data Analyst') ]

# %% [markdown]
# # Explore Dataset check each column and values associated

# %%
df_plot = df_da_us['job_location'].value_counts().head(10).to_frame()
df_plot
# Out:
#                  count
# job_location
# Anywhere          4548
# New York, NY      2646
# Atlanta, GA       2335
# Chicago, IL       2051
# Austin, TX        1673
# Dallas, TX        1561
# Washington, DC    1396
# Charlotte, NC     1219
# Tampa, FL         1208
# Los Angeles, CA   1098

# %%
sns.set_theme (style='whitegrid')
sns.barplot(
    data= df_plot,
    x= 'count',
    y= 'job_location',
    hue= 'count',
    palette= 'light:g'
)
# Out:
# <Axes: xlabel='count', ylabel='job_location'>

# %% [markdown]
# # Explore Company column

# %%
df_company = df_da_us['company_name'].value_counts().head(10).to_frame()

# %%
sns.barplot(
    data= df_company, 
    y= 'company_name', 
    x='count', 
    hue= 'count', 
    palette= 'light:b')
# Out:
# <Axes: xlabel='count', ylabel='company_name'>
